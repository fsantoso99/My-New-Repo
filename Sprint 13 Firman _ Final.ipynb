# %% [markdown]
# # Tahap Penguraian Tugas

# %% [markdown]
# ## Deskripsi Proyek

# %% [markdown]
# Dataset utama memuat data terkait peristiwa yang dilalui para pemain untuk game seluler "Space Brothers".
#
# Penerapan monetisasi utama game ini masih dalam tahap perencanaan. Perusahaan mengharapkan bahwa nantinya, aplikasi ini akan menayangkan sejumlah iklan pada layar saat pengguna memilih jenis objek yang akan dibangun.
#
# Dataset yang tersedia berisi data tentang para pengguna di level pertama game. Agar bisa melanjutkan ke level kedua, pemain harus melakukan salah satu aktivitas berikut:
#
# - Mengalahkan bos pertamanya
# - Membangun sistem perakitan satelit orbit

# %% [markdown]
# ### Tujuan Proyek

# %% [markdown]
# Adapun beberapa tujuan proyek yang akan kita dapatkan dati dataset tersebut :
#
# - Mencari sumber iklan yang paling menguntungkan dalam mengakuisisi pengguna
# - Apa yang bisa lakukan supaya cost efficient dengan hasil user yang maksimal
# - Menentukan kapan moment yang tepat untuk memonetisasi iklan

# %% [markdown]
# ### Menentukan detail dan Batas-Batas Proyek

# %% [markdown]
# Adapun beberapa batasan dalam proyek yang kita perlu tahu
#
# - Hasil proyek ini akan di bawa ke top management
# - Data yang di berikan jika parameter tidak lengkap bisa menggunakan refrensi yang relevan.

# %% [markdown]
# ### Refrensi project

# %% [markdown]
# * Refrensi : https://www.niagahoster.co.id/blog/jenis-iklan-online/
#
#     * Keuntungan Menggunakan Online Marketing untuk Mendapatkan Pengguna
#         1. Iklan Lebih Terukur : Iklan online sangat memudahkan Anda dalam melakukan analisa. Anda bisa dengan jelas memantau  keefektifan iklan mulai dari jangkauan, biaya, hingga target iklan Anda. Platform iklan sudah menyediakan berbagai pelaporan data yang bisa Anda analisa untuk menentukan target iklan Anda selanjutnya.
#         2. Iklan Online Lebih Beragam Formatnya : iklan online memilki keuntungan berupa kebebasan dalam menentukan jenis dan format iklan. Mulai dari gambar, video, teks, hingga kombinasi antara ketiganya bisa Anda gunakan sesuai kebutuhan.
#
#
#
# * Refrensi : https://id-id.facebook.com/audiencenetwork/news-and-insights/winning-strategies-for-monetizing-your-game-with-ads
#
#     * Strategi Keberhasilan untuk Memonetisasi Game Anda dengan Iklan
#         1. Momen yang tepat untuk menyisipkan iklan pada game untuk mendorong pendapatan Konten dan iklan menggunakan Jenis Alur ,
#             * Penemuan: Seorang pemain cenderung lebih memperhatikan iklan saat dalam mode penemuan; selama aktivitas yang bukan merupakan fokus utama dari aplikasi. Misalnya, iklan dapat diintegrasikan untuk muncul saat pemain melihat tab notifikasi. Karena ini merupakan tindakan yang diinisiasi oleh pengguna, penempatan ad discovery dapat bermanfaat terutama untuk membantu mendorong konversi.
#             * Setelah Tugas: Jeda saat interaksi iklan adalah saat pemain game cenderung mulai memperhatikan sebuah iklan. Misalnya, menampilkan iklan saat seseorang sudah menyelesaikan tindakannya, seperti membersihkan memori.

# %% [markdown]
# ### Mengajukan Hipotesis

# %% [markdown]
# Hipotesis yang bisa di lakukan :
#
# - Hipotesis tentang perbedaan waktu penyelesaian level antara pengguna yang **menyelesaikan level dengan proyek** dan yang menyelesaikannya dengan **mengalahkan pemain lain.**
# - Hipotesis tentang perbedaan rata-rata **jumlah bangunan yang dibangun oleh pengguna** yang **menyelesaikan level melalui proyek dan dengan mengalahkan pemain lain**

# %% [markdown]
# ### Mengubah Hipotesis menjadi Rencana Tindakan yang Nyata

# %% [markdown]
# - menghitung min dan max waktu tiap jenis banugnan dan aktivitas menyelesaikan bos tiap user user
# - menghitung jumlah waktu yang dilewati tiap user dan jenis aktifitas
# - menghitng rata-rata waktu yang di butuhkan membangun jenis bangunan dan aktifitas mengalahkan bos tiap user
# - analisa rata-rata waktu yang dilewati untuk disisipkan iklan.

# %% [markdown]
# ### Menambahkan Tahap-Tahap Wajib Analisis

# %% [markdown]
# untuk menyelesaikan proyek kita perlu tahapan wajib yang perlu dilewati sebelum menyimpulan tujuan dan hipotesis kita :

# %% [markdown]
# * Pra-pemrosesan data :
#
#     - Mempelajari nilai-nilai yang hilang
#     - Mempelajari tipe data
#     - Mempelajari nilai-nilai duplikat
#     - Menghapus duplikat
#     - Mengonversi tipe data
#     - Mengganti nilai-nilai yang hilang
#
#
# * Analisa data exploratif :
#
#     - Analisa Biaya Customer Per Aqcuisition
#     - Analisa Waktu persitiwa yang di lewati pengguna dan mempelajarinya
#
#
# * Mengidentifikasi hubungan source dan hasil user pada setiap peristiwa / jenis bangunan

# %% [markdown]
# ### Pengambilan Kesimpulan dan Rencana Apa yang Akan Diambil

# %% [markdown]
# Kesimpulan nanti yang akan kita analisa adalah sumber iklan mana yang efektif untuk mengiklan, kita lihat CAC-nya yang murah paling tidak dari beberapa sumber kita optimalkan 3 sumber terbaik. lalu kita analisa pengguna yang menyelesaikan project hingga selesai berasal dari sumber mana dan rata-rata spentnya berapa lama. untuk nantinya kita akan memonetitasi iklan ke pengguna yang tepat
#
#
# rencana yang akan kita ambil untuk mendapatkan tujuan tersebut, kita beda datanya dulu. untuk mencari CAC-nya kita gabungkan dataset cost dan event, dapatkan pengguna yang di dapat dari biaya iklan.  cari mana yang paling baik pterformanya

# %% [markdown]
# ## Penguraian Data - Pra proses

# %% [markdown]
# ### Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats as st
import seaborn as sns

# %% [markdown]
# ### Peninjauan Data

# %% [markdown]
# #### Data Events

# %% [markdown]
# Mari kita buka data Event

# %%
df_event = pd.read_csv('games/events_us.csv')
df_event
# Out:
#              event_datetime             event    building_type  \
# 0       2020-05-04 00:00:01          building    assembly_shop
# 1       2020-05-04 00:00:03          building    assembly_shop
# 2       2020-05-04 00:00:16          building    assembly_shop
# 3       2020-05-04 00:00:16          building    assembly_shop
# 4       2020-05-04 00:00:35          building    assembly_shop
# ...                     ...               ...              ...
# 135635  2020-06-05 00:08:06          building  research_center
# 135636  2020-06-05 02:25:12  finished_stage_1              NaN
# 135637  2020-06-05 08:57:52          building  research_center
# 135638  2020-06-05 12:12:27  finished_stage_1              NaN
# 135639  2020-06-05 12:32:49  finished_stage_1              NaN
#
#                                      user_id project_type
# 0       55e92310-cb8e-4754-b622-597e124b03de          NaN
# 1       c07b1c10-f477-44dc-81dc-ec82254b1347          NaN
# ...

# %%
df_event.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135640 entries, 0 to 135639
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   event_datetime  135640 non-null  object
#  1   event           135640 non-null  object
#  2   building_type   127957 non-null  object
#  3   user_id         135640 non-null  object
#  4   project_type    1866 non-null    object
# dtypes: object(5)
# memory usage: 5.2+ MB

# %%
df_event.describe()
# Out:
#              event_datetime     event building_type  \
# count                135640    135640        127957
# unique               128790         3             3
# top     2020-05-08 22:30:04  building     spaceport
# freq                      4    127957         59325
#
#                                      user_id                project_type
# count                                 135640                        1866
# unique                                 13576                           1
# top     d6aca06a-cd75-4cd8-b8cd-240a3c163884  satellite_orbital_assembly
# freq                                      22                        1866

# %%
title_column = ['event','building_type','project_type']

for column in title_column:
    print(df_event[column].value_counts())
    print()
# Out:
# building            127957
# finished_stage_1      5817
# project               1866
# Name: event, dtype: int64
#
# spaceport          59325
# assembly_shop      54494
# research_center    14138
# Name: building_type, dtype: int64
#
# satellite_orbital_assembly    1866
# Name: project_type, dtype: int64

# %% [markdown]
# ada tipe data yang kurang cocok pada event_datetime, kita perlu rubah seperti dahulu selain itu ada data yang hilang pada building_type dan project type, perlu di pelajarai lebih lanjut

# %%
df_event['event_datetime'] = pd.to_datetime(df_event['event_datetime'])
df_event.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135640 entries, 0 to 135639
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   event_datetime  135640 non-null  datetime64[ns]
#  1   event           135640 non-null  object
#  2   building_type   127957 non-null  object
#  3   user_id         135640 non-null  object
#  4   project_type    1866 non-null    object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 5.2+ MB

# %% [markdown]
# kita perlu periksa apa ada data yang duplicate.

# %%
df_event[df_event.duplicated()]
# Out:
#            event_datetime     event    building_type  \
# 74891 2020-05-10 18:41:56  building  research_center
#
#                                     user_id project_type
# 74891  c9af55d2-b0ae-4bb4-b3d5-f32aa9ac03af          NaN

# %% [markdown]
# ada 1 data kita perlu hilangkan.

# %%
df_event = df_event.drop_duplicates()
df_event.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 135639 entries, 0 to 135639
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   event_datetime  135639 non-null  datetime64[ns]
#  1   event           135639 non-null  object
#  2   building_type   127956 non-null  object
#  3   user_id         135639 non-null  object
#  4   project_type    1866 non-null    object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 6.2+ MB

# %% [markdown]
# ada 2 kolom yang mengalami data yang hilang. kita perlu mempelajari dan memeriksa masing-masing

# %% [markdown]
# **building_type**

# %%
building_type_nan = df_event[df_event['building_type'].isna()]
building_type_nan
# Out:
#             event_datetime             event building_type  \
# 6659   2020-05-04 19:47:29  finished_stage_1           NaN
# 13134  2020-05-05 13:22:09  finished_stage_1           NaN
# 15274  2020-05-05 18:54:37  finished_stage_1           NaN
# 16284  2020-05-05 21:27:29  finished_stage_1           NaN
# 19650  2020-05-06 06:02:22  finished_stage_1           NaN
# ...                    ...               ...           ...
# 135632 2020-06-04 15:50:38  finished_stage_1           NaN
# 135633 2020-06-04 17:56:14  finished_stage_1           NaN
# 135636 2020-06-05 02:25:12  finished_stage_1           NaN
# 135638 2020-06-05 12:12:27  finished_stage_1           NaN
# 135639 2020-06-05 12:32:49  finished_stage_1           NaN
#
#                                      user_id project_type
# 6659    ced7b368-818f-48f6-9461-2346de0892c5          NaN
# 13134   7ef7fc89-2779-46ea-b328-9e5035b83af5          NaN
# 15274   70db22b3-c2f4-43bc-94ea-51c8d2904a29          NaN
# ...

# %% [markdown]
# jika kita lihat semua eventnnya adalah 'finished_stage_1'. kita check apalah ada value selain itu

# %%
title_column_event_nan = ['event','building_type','project_type']

for column in title_column_event_nan:
    print(building_type_nan[column].value_counts())
    print()
# Out:
# finished_stage_1    5817
# project             1866
# Name: event, dtype: int64
#
# Series([], Name: building_type, dtype: int64)
#
# satellite_orbital_assembly    1866
# Name: project_type, dtype: int64

# %% [markdown]
# kita buka event 'project'

# %%
building_type_nan[building_type_nan['event'] == 'project']
# Out:
#             event_datetime    event building_type  \
# 47121  2020-05-08 18:10:25  project           NaN
# 57398  2020-05-09 13:49:11  project           NaN
# 58797  2020-05-09 16:19:33  project           NaN
# 61174  2020-05-09 20:29:01  project           NaN
# 63770  2020-05-10 00:57:47  project           NaN
# ...                    ...      ...           ...
# 135602 2020-06-02 03:04:42  project           NaN
# 135603 2020-06-02 06:21:03  project           NaN
# 135609 2020-06-02 17:17:28  project           NaN
# 135617 2020-06-03 09:46:04  project           NaN
# 135630 2020-06-04 08:29:42  project           NaN
#
#                                      user_id                project_type
# 47121   e3c66498-9d45-4000-9392-f81e6796e7da  satellite_orbital_assembly
# 57398   936e7af6-8338-4703-a1df-fc6c3f5b8e34  satellite_orbital_assembly
# 58797   a4491c86-c498-4f74-a56e-65c136d0e9a1  satellite_orbital_assembly
# ...

# %%
df_event['building_type'].fillna('next_level', inplace=True)
df_event
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
#             event_datetime             event    building_type  \
# 0      2020-05-04 00:00:01          building    assembly_shop
# 1      2020-05-04 00:00:03          building    assembly_shop
# 2      2020-05-04 00:00:16          building    assembly_shop
# 3      2020-05-04 00:00:16          building    assembly_shop
# 4      2020-05-04 00:00:35          building    assembly_shop
# ...                    ...               ...              ...
# 135635 2020-06-05 00:08:06          building  research_center
# 135636 2020-06-05 02:25:12  finished_stage_1       next_level
# 135637 2020-06-05 08:57:52          building  research_center
# ...

# %% [markdown]
# kita bisa lihat hasil yang kita dapatkan bahwa jika pengguna sudah menyelesaikan level 1 dan menyusun satelit orbital maka hasilnya 'Nan' yang artinya sudah selesai pada level 1. jadi kita tidak perlu mengisi data yang kosong ini namun untuk yang finished stage perlu di isi jika nanti di butuhkan

# %% [markdown]
# **project_type**

# %%
project_type_nan = df_event[df_event['project_type'].isna()]
project_type_nan
# Out:
#             event_datetime             event    building_type  \
# 0      2020-05-04 00:00:01          building    assembly_shop
# 1      2020-05-04 00:00:03          building    assembly_shop
# 2      2020-05-04 00:00:16          building    assembly_shop
# 3      2020-05-04 00:00:16          building    assembly_shop
# 4      2020-05-04 00:00:35          building    assembly_shop
# ...                    ...               ...              ...
# 135635 2020-06-05 00:08:06          building  research_center
# 135636 2020-06-05 02:25:12  finished_stage_1       next_level
# 135637 2020-06-05 08:57:52          building  research_center
# 135638 2020-06-05 12:12:27  finished_stage_1       next_level
# 135639 2020-06-05 12:32:49  finished_stage_1       next_level
#
#                                      user_id project_type
# 0       55e92310-cb8e-4754-b622-597e124b03de          NaN
# 1       c07b1c10-f477-44dc-81dc-ec82254b1347          NaN
# ...

# %%
title_column_project_type_nan = ['event','building_type','project_type']

for column in title_column_project_type_nan:
    print(project_type_nan[column].value_counts())
    print()
# Out:
# building            127956
# finished_stage_1      5817
# Name: event, dtype: int64
#
# spaceport          59325
# assembly_shop      54494
# research_center    14137
# next_level          5817
# Name: building_type, dtype: int64
#
# Series([], Name: project_type, dtype: int64)

# %% [markdown]
# data di atas mengkonfirmasi lagi untuk yang tidak mengambil project satelit maka project typenya NaN, dan kolom event hanya buildng dan finished_stage_1, tidak ada event project. jadi tidak ada yang perlu di isi atas kehilangan data pada kedua kolom.

# %% [markdown]
# #### Data User

# %%
df_user = pd.read_csv('games/user_source_us.csv')
df_user
# Out:
#                                     user_id  event_date  \
# 0      0001f83c-c6ac-4621-b7f0-8a28b283ac30  2020-05-06
# 1      00151b4f-ba38-44a8-a650-d7cf130a0105  2020-05-06
# 2      001aaea6-3d14-43f1-8ca8-7f48820f17aa  2020-05-05
# 3      001d39dc-366c-4021-9604-6a3b9ff01e25  2020-05-05
# 4      002f508f-67b6-479f-814b-b05f00d4e995  2020-05-05
# ...                                     ...         ...
# 13571  ffef4fed-164c-40e1-bde1-3980f76d0fb5  2020-05-04
# 13572  fffab3da-da0e-4e30-ae62-10d0a2e24a4e  2020-05-04
# 13573  fffb626c-5ab6-47c9-8113-2062a2f18494  2020-05-04
# 13574  ffff194a-56b7-4c12-860d-3485242ae7f5  2020-05-04
# 13575  ffff69cc-fec1-4fd3-9f98-93be1112a6b8  2020-05-08
#
#                         source
# 0                 facebook_ads
# 1              google_play_ads
# 2      youtube_channel_network
# 3        instagram_new_adverts
# 4                 facebook_ads
# ...                        ...
# 13571    instagram_new_adverts
# 13572             facebook_ads
# ...

# %%
df_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13576 entries, 0 to 13575
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     13576 non-null  object
#  1   event_date  13576 non-null  object
#  2   source      13576 non-null  object
# dtypes: object(3)
# memory usage: 318.3+ KB

# %%
df_user.describe()
# Out:
#                                      user_id  event_date           source
# count                                  13576       13576            13576
# unique                                 13576           7                4
# top     cdf89d95-fc76-4010-bc51-1ea7a6bf0a2b  2020-05-04  google_play_ads
# freq                                       1        5860             4817

# %%
df_user['event_date'] = pd.to_datetime(df_user['event_date'])
df_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13576 entries, 0 to 13575
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     13576 non-null  object
#  1   event_date  13576 non-null  datetime64[ns]
#  2   source      13576 non-null  object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 318.3+ KB

# %%
df_user_col = ['event_date','source']

for column in df_user_col:
    print(df_user[column].value_counts())
    print()
# Out:
# 2020-05-04    5860
# 2020-05-05    3361
# 2020-05-06    1847
# 2020-05-07    1109
# 2020-05-08     688
# 2020-05-09     440
# 2020-05-10     271
# Name: event_date, dtype: int64
#
# google_play_ads            4817
# instagram_new_adverts      3347
# facebook_ads               2726
# youtube_channel_network    2686
# Name: source, dtype: int64

# %% [markdown]
# dapat kita lihat yang paling banyak meng-klik iklan pada tanggal 4, 5 dan 6. paling banyak user meng-klik lewat google_play_ads

# %% [markdown]
# dari data user ini tidak ada kendata data hilang dan tipe data. kita bisa lanjutkan

# %% [markdown]
# #### Data Ads

# %%
df_ads = pd.read_csv('games/ad_costs_us.csv')
df_ads
# Out:
#                      source         day        cost
# 0              facebook_ads  2020-05-03  935.882786
# 1              facebook_ads  2020-05-04  548.354480
# 2              facebook_ads  2020-05-05  260.185754
# 3              facebook_ads  2020-05-06  177.982200
# 4              facebook_ads  2020-05-07  111.766796
# 5              facebook_ads  2020-05-08   68.009276
# 6              facebook_ads  2020-05-09   38.723350
# 7     instagram_new_adverts  2020-05-03  943.204717
# 8     instagram_new_adverts  2020-05-04  502.925451
# 9     instagram_new_adverts  2020-05-05  313.970984
# 10    instagram_new_adverts  2020-05-06  173.071145
# 11    instagram_new_adverts  2020-05-07  109.915254
# 12    instagram_new_adverts  2020-05-08   71.578739
# 13    instagram_new_adverts  2020-05-09   46.775400
# 14          google_play_ads  2020-05-03  969.139394
# 15          google_play_ads  2020-05-04  554.651494
# 16          google_play_ads  2020-05-05  308.232990
# ...

# %%
df_ads['day'] = pd.to_datetime(df_ads['day'])
df_ads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   source  28 non-null     object
#  1   day     28 non-null     datetime64[ns]
#  2   cost    28 non-null     float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 800.0+ bytes

# %% [markdown]
# untuk data ads tidak ada masalah mengenai duplikat dan data yang hilang. kita bisa lanjutkan ke analisa data eksploratif

# %% [markdown]
# ## Penguraian Data - Analisa Data Ekploratif

# %% [markdown]
# ### Analisa Biaya Customer Aquisition Cost

# %%
df_user
# Out:
#                                     user_id event_date  \
# 0      0001f83c-c6ac-4621-b7f0-8a28b283ac30 2020-05-06
# 1      00151b4f-ba38-44a8-a650-d7cf130a0105 2020-05-06
# 2      001aaea6-3d14-43f1-8ca8-7f48820f17aa 2020-05-05
# 3      001d39dc-366c-4021-9604-6a3b9ff01e25 2020-05-05
# 4      002f508f-67b6-479f-814b-b05f00d4e995 2020-05-05
# ...                                     ...        ...
# 13571  ffef4fed-164c-40e1-bde1-3980f76d0fb5 2020-05-04
# 13572  fffab3da-da0e-4e30-ae62-10d0a2e24a4e 2020-05-04
# 13573  fffb626c-5ab6-47c9-8113-2062a2f18494 2020-05-04
# 13574  ffff194a-56b7-4c12-860d-3485242ae7f5 2020-05-04
# 13575  ffff69cc-fec1-4fd3-9f98-93be1112a6b8 2020-05-08
#
#                         source
# 0                 facebook_ads
# 1              google_play_ads
# 2      youtube_channel_network
# 3        instagram_new_adverts
# 4                 facebook_ads
# ...                        ...
# 13571    instagram_new_adverts
# 13572             facebook_ads
# ...

# %%
df_customer_source = df_user.groupby(['source','event_date']).agg({'user_id':'count'}).reset_index()
df_customer_source = df_customer_source.rename(columns={'event_date': 'day'})
df_customer_source
# Out:
#                      source        day  user_id
# 0              facebook_ads 2020-05-04     1184
# 1              facebook_ads 2020-05-05      694
# 2              facebook_ads 2020-05-06      345
# 3              facebook_ads 2020-05-07      224
# 4              facebook_ads 2020-05-08      139
# 5              facebook_ads 2020-05-09       84
# 6              facebook_ads 2020-05-10       56
# 7           google_play_ads 2020-05-04     2078
# 8           google_play_ads 2020-05-05     1208
# 9           google_play_ads 2020-05-06      664
# 10          google_play_ads 2020-05-07      395
# 11          google_play_ads 2020-05-08      239
# 12          google_play_ads 2020-05-09      144
# 13          google_play_ads 2020-05-10       89
# 14    instagram_new_adverts 2020-05-04     1452
# 15    instagram_new_adverts 2020-05-05      796
# 16    instagram_new_adverts 2020-05-06      472
# 17    instagram_new_adverts 2020-05-07      270
# 18    instagram_new_adverts 2020-05-08      175
# ...

# %%
df_ads
# Out:
#                      source        day        cost
# 0              facebook_ads 2020-05-03  935.882786
# 1              facebook_ads 2020-05-04  548.354480
# 2              facebook_ads 2020-05-05  260.185754
# 3              facebook_ads 2020-05-06  177.982200
# 4              facebook_ads 2020-05-07  111.766796
# 5              facebook_ads 2020-05-08   68.009276
# 6              facebook_ads 2020-05-09   38.723350
# 7     instagram_new_adverts 2020-05-03  943.204717
# 8     instagram_new_adverts 2020-05-04  502.925451
# 9     instagram_new_adverts 2020-05-05  313.970984
# 10    instagram_new_adverts 2020-05-06  173.071145
# 11    instagram_new_adverts 2020-05-07  109.915254
# 12    instagram_new_adverts 2020-05-08   71.578739
# 13    instagram_new_adverts 2020-05-09   46.775400
# 14          google_play_ads 2020-05-03  969.139394
# 15          google_play_ads 2020-05-04  554.651494
# 16          google_play_ads 2020-05-05  308.232990
# ...

# %% [markdown]
# setelah itu kita akan merge berdasarkan source dan day

# %%
df_cac = df_ads.merge(df_customer_source , on =['source','day',])
df_cac['cac'] = df_cac['cost']/df_cac['user_id']
df_cac
# Out:
#                      source        day        cost  user_id       cac
# 0              facebook_ads 2020-05-04  548.354480     1184  0.463137
# 1              facebook_ads 2020-05-05  260.185754      694  0.374907
# 2              facebook_ads 2020-05-06  177.982200      345  0.515890
# 3              facebook_ads 2020-05-07  111.766796      224  0.498959
# 4              facebook_ads 2020-05-08   68.009276      139  0.489275
# 5              facebook_ads 2020-05-09   38.723350       84  0.460992
# 6     instagram_new_adverts 2020-05-04  502.925451     1452  0.346367
# 7     instagram_new_adverts 2020-05-05  313.970984      796  0.394436
# 8     instagram_new_adverts 2020-05-06  173.071145      472  0.366676
# 9     instagram_new_adverts 2020-05-07  109.915254      270  0.407094
# 10    instagram_new_adverts 2020-05-08   71.578739      175  0.409021
# 11    instagram_new_adverts 2020-05-09   46.775400      112  0.417637
# ...

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_cac, x='day', y='cac', hue='source')
plt.title('CAC by Source Over Time')
plt.xlabel('Date')
plt.ylabel('CAC')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# bisa kita lihat grafik di atas CAC cukup variatif namun tiap sumber yang berbeda mempunyai pola yang sama, sepanjang waktu nilai CACnya tidak ada perbedaan yang signifikan, namun ada perbedaan nilai CAC berdasarkan sumbernya, untuk youtube dan google mempunyai posisi paling murah dan untuk facebook dan instagram mempunyai CAC yang begitu tinggi.

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_cac, x='day', y='cost', hue='source')
plt.title('Cost by Source Over Time')
plt.xlabel('Date')
plt.ylabel('Cost')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# kits bisa lihat grafik di atas yaitu korelasi cost terhadap waktu, sepanjang waktu cost yang di gunakan menurun secara exponential, namun pada saat di awa bulan budget iklan untuk youtube merupakan paling kecil.

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_cac, x='day', y='user_id', hue='source')
plt.title('User_id by Source Over Time')
plt.xlabel('Date')
plt.ylabel('User_id')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# kita bisa lihat grafik di atas adalah user yang di dapatkan sepanjnag waktu, secara trend hasilnya menurun secara exponential.
# pada hari pertama google menempati posisi terbanyak mendapatkan customer di banding sumber lainnya

# %% [markdown]
# sekarang kita coba group berdasarkan source aja

# %%
df_cac_1 = df_cac.groupby('source').agg({'cost':'sum','user_id':'sum'})
df_cac_1['cac'] = df_cac_1['cost']/df_cac_1['user_id']
df_cac_1 = df_cac_1.reset_index()
df_cac_1
# Out:
#                     source         cost  user_id       cac
# 0             facebook_ads  1205.021857     2670  0.451319
# 1          google_play_ads  1263.972055     4728  0.267338
# 2    instagram_new_adverts  1218.236973     3277  0.371754
# 3  youtube_channel_network   613.894261     2630  0.233420

# %%
plt.figure(figsize=(10, 6))

plt.bar(df_cac_1['source'], df_cac_1['cac'], color='blue')
plt.xlabel('Source')
plt.ylabel('Customer Acquisition Cost (CAC)')
plt.title('CAC by Source')
plt.xticks(rotation=45)
plt.tight_layout()

# %% [markdown]
# dari hasil analisa CAC kita, untuk yang harian dapat kita lihat bahwa spend makin besar tidak berarti "cac"nya makin murah. ada hari yang memang "cac"nya lebh murah.
#
# untuk analisa jika kita group berdasarkan source saja di dapat bawah cac paling murah ada pada source youtube_channel_network, akusisi customernya terbanyak ada di google, lalu di susul oleh instagram, namun CAC lebih mahal di banding youtube_channel_network

# %% [markdown]
# ### Analisa Waktu persitiwa yang di lewati pengguna dan mempelajarinya

# %%
df_event
# Out:
#             event_datetime             event    building_type  \
# 0      2020-05-04 00:00:01          building    assembly_shop
# 1      2020-05-04 00:00:03          building    assembly_shop
# 2      2020-05-04 00:00:16          building    assembly_shop
# 3      2020-05-04 00:00:16          building    assembly_shop
# 4      2020-05-04 00:00:35          building    assembly_shop
# ...                    ...               ...              ...
# 135635 2020-06-05 00:08:06          building  research_center
# 135636 2020-06-05 02:25:12  finished_stage_1       next_level
# 135637 2020-06-05 08:57:52          building  research_center
# 135638 2020-06-05 12:12:27  finished_stage_1       next_level
# 135639 2020-06-05 12:32:49  finished_stage_1       next_level
#
#                                      user_id project_type
# 0       55e92310-cb8e-4754-b622-597e124b03de          NaN
# 1       c07b1c10-f477-44dc-81dc-ec82254b1347          NaN
# ...

# %%
df_event['user_id'].value_counts()
# Out:
# d6aca06a-cd75-4cd8-b8cd-240a3c163884    22
# ff841992-d93b-462e-bc6e-18c24a514f36    22
# bf542075-e3a2-4e79-82d8-3838e86d2a25    22
# 2f4c1905-e7c9-4b75-b265-1d80abf49f1d    21
# c133dd1d-c5d0-48e8-aaf7-f654be5b9b56    21
#                                         ..
# 48a96c0c-7c59-4f43-a694-58568b8c6820     1
# 31d67118-da17-4d29-8d42-da15aaca6eb7     1
# 545d5caa-999d-4f5f-a192-dee4d66d2f9d     1
# 3d2ac4d1-a405-4d14-b6e6-4ff5884d4f88     1
# 886c3d2d-a547-4f46-9d03-0722ba3b3f5e     1
# Name: user_id, Length: 13576, dtype: int64

# %% [markdown]
# ada beberapa user yang melakukan peristiwa beberapa kali. perlu di analisa lebih lanjut

# %% [markdown]
# mari kita ambil sample 1 user id : d6aca06a-cd75-4cd8-b8cd-240a3c163884

# %%
df_event[df_event['user_id'] == 'd6aca06a-cd75-4cd8-b8cd-240a3c163884'].sort_values(by = 'event_datetime')
# Out:
#             event_datetime             event    building_type  \
# 3436   2020-05-04 10:30:08          building    assembly_shop
# 7535   2020-05-04 22:12:18          building    assembly_shop
# 8682   2020-05-05 01:24:42          building    assembly_shop
# 11407  2020-05-05 08:48:41          building    assembly_shop
# 31301  2020-05-07 09:19:26          building    assembly_shop
# 35448  2020-05-07 18:30:51          building    assembly_shop
# 44878  2020-05-08 13:46:10          building        spaceport
# 49807  2020-05-08 23:26:29          building        spaceport
# 63084  2020-05-09 23:48:52          building    assembly_shop
# 71172  2020-05-10 13:00:12          building        spaceport
# 77229  2020-05-10 22:17:07          building        spaceport
# 79044  2020-05-11 01:57:55          building  research_center
# 95821  2020-05-13 04:03:27          building  research_center
# 104637 2020-05-14 08:36:28          building  research_center
# ...

# %% [markdown]
# ada user yang sering muncul walaupun sudah menyelesaikan salah 1 aktifitas menyusun satelit / finish stage 1.

# %%
df_user_spent_time = df_event.groupby(['user_id', 'event', 'building_type']).agg({'event_datetime': ['max']})
df_user_spent_time = df_user_spent_time.reset_index()
df_user_spent_time.columns = ['user_id', 'event', 'building_type', 'event_datetime_max']
df_user_spent_time
# Out:
#                                     user_id             event  \
# 0      0001f83c-c6ac-4621-b7f0-8a28b283ac30          building
# 1      0001f83c-c6ac-4621-b7f0-8a28b283ac30          building
# 2      0001f83c-c6ac-4621-b7f0-8a28b283ac30          building
# 3      00151b4f-ba38-44a8-a650-d7cf130a0105          building
# 4      00151b4f-ba38-44a8-a650-d7cf130a0105          building
# ...                                     ...               ...
# 42156  ffff69cc-fec1-4fd3-9f98-93be1112a6b8          building
# 42157  ffff69cc-fec1-4fd3-9f98-93be1112a6b8          building
# 42158  ffff69cc-fec1-4fd3-9f98-93be1112a6b8          building
# 42159  ffff69cc-fec1-4fd3-9f98-93be1112a6b8  finished_stage_1
# 42160  ffff69cc-fec1-4fd3-9f98-93be1112a6b8           project
#
#          building_type  event_datetime_max
# 0        assembly_shop 2020-05-09 17:36:38
# 1      research_center 2020-05-20 11:26:06
# 2            spaceport 2020-05-19 02:44:08
# 3        assembly_shop 2020-05-09 21:46:24
# ...

# %% [markdown]
# sekarang kita coba joinkan dengan df_user supaya data yang kita punya lebih lengkap

# %%
df_user
# Out:
#                                     user_id event_date  \
# 0      0001f83c-c6ac-4621-b7f0-8a28b283ac30 2020-05-06
# 1      00151b4f-ba38-44a8-a650-d7cf130a0105 2020-05-06
# 2      001aaea6-3d14-43f1-8ca8-7f48820f17aa 2020-05-05
# 3      001d39dc-366c-4021-9604-6a3b9ff01e25 2020-05-05
# 4      002f508f-67b6-479f-814b-b05f00d4e995 2020-05-05
# ...                                     ...        ...
# 13571  ffef4fed-164c-40e1-bde1-3980f76d0fb5 2020-05-04
# 13572  fffab3da-da0e-4e30-ae62-10d0a2e24a4e 2020-05-04
# 13573  fffb626c-5ab6-47c9-8113-2062a2f18494 2020-05-04
# 13574  ffff194a-56b7-4c12-860d-3485242ae7f5 2020-05-04
# 13575  ffff69cc-fec1-4fd3-9f98-93be1112a6b8 2020-05-08
#
#                         source
# 0                 facebook_ads
# 1              google_play_ads
# 2      youtube_channel_network
# 3        instagram_new_adverts
# 4                 facebook_ads
# ...                        ...
# 13571    instagram_new_adverts
# 13572             facebook_ads
# ...

# %%
df_user_spent_time = df_user_spent_time.merge(df_user[['user_id', 'source','event_date']], on='user_id', how='left')

# %%
df_user_spent_time = df_user_spent_time.rename(columns={'source_y':'source'})
df_user_spent_time
# Out:
#                                     user_id             event  \
# 0      0001f83c-c6ac-4621-b7f0-8a28b283ac30          building
# 1      0001f83c-c6ac-4621-b7f0-8a28b283ac30          building
# 2      0001f83c-c6ac-4621-b7f0-8a28b283ac30          building
# 3      00151b4f-ba38-44a8-a650-d7cf130a0105          building
# 4      00151b4f-ba38-44a8-a650-d7cf130a0105          building
# ...                                     ...               ...
# 42156  ffff69cc-fec1-4fd3-9f98-93be1112a6b8          building
# 42157  ffff69cc-fec1-4fd3-9f98-93be1112a6b8          building
# 42158  ffff69cc-fec1-4fd3-9f98-93be1112a6b8          building
# 42159  ffff69cc-fec1-4fd3-9f98-93be1112a6b8  finished_stage_1
# 42160  ffff69cc-fec1-4fd3-9f98-93be1112a6b8           project
#
#          building_type  event_datetime_max           source event_date
# 0        assembly_shop 2020-05-09 17:36:38     facebook_ads 2020-05-06
# 1      research_center 2020-05-20 11:26:06     facebook_ads 2020-05-06
# ...

# %%
df_user_spent_time['spend_time'] = df_user_spent_time['event_datetime_max'] - df_user_spent_time['event_date']

df_user_spent_time['days'] = df_user_spent_time['spend_time'].dt.days
df_user_spent_time['hours'] = df_user_spent_time['spend_time'].dt.seconds // 3600
df_user_spent_time['minutes'] = (df_user_spent_time['spend_time'].dt.seconds // 60) % 60

df_user_spent_time['total_hours_spend'] = df_user_spent_time['days'] * 24 + df_user_spent_time['hours'] + df_user_spent_time['minutes'] / 60

df_user_spent_time = df_user_spent_time.drop(columns=['days', 'hours', 'minutes'])

df_user_spent_time
# Out:
#                                     user_id             event  \
# 0      0001f83c-c6ac-4621-b7f0-8a28b283ac30          building
# 1      0001f83c-c6ac-4621-b7f0-8a28b283ac30          building
# 2      0001f83c-c6ac-4621-b7f0-8a28b283ac30          building
# 3      00151b4f-ba38-44a8-a650-d7cf130a0105          building
# 4      00151b4f-ba38-44a8-a650-d7cf130a0105          building
# ...                                     ...               ...
# 42156  ffff69cc-fec1-4fd3-9f98-93be1112a6b8          building
# 42157  ffff69cc-fec1-4fd3-9f98-93be1112a6b8          building
# 42158  ffff69cc-fec1-4fd3-9f98-93be1112a6b8          building
# 42159  ffff69cc-fec1-4fd3-9f98-93be1112a6b8  finished_stage_1
# 42160  ffff69cc-fec1-4fd3-9f98-93be1112a6b8           project
#
#          building_type  event_datetime_max           source event_date  \
# 0        assembly_shop 2020-05-09 17:36:38     facebook_ads 2020-05-06
# 1      research_center 2020-05-20 11:26:06     facebook_ads 2020-05-06
# ...

# %% [markdown]
# #### Data bersih untuk di lanjut analisa

# %%
df_user_spent_time
# Out:
#                                     user_id             event  \
# 0      0001f83c-c6ac-4621-b7f0-8a28b283ac30          building
# 1      0001f83c-c6ac-4621-b7f0-8a28b283ac30          building
# 2      0001f83c-c6ac-4621-b7f0-8a28b283ac30          building
# 3      00151b4f-ba38-44a8-a650-d7cf130a0105          building
# 4      00151b4f-ba38-44a8-a650-d7cf130a0105          building
# ...                                     ...               ...
# 42156  ffff69cc-fec1-4fd3-9f98-93be1112a6b8          building
# 42157  ffff69cc-fec1-4fd3-9f98-93be1112a6b8          building
# 42158  ffff69cc-fec1-4fd3-9f98-93be1112a6b8          building
# 42159  ffff69cc-fec1-4fd3-9f98-93be1112a6b8  finished_stage_1
# 42160  ffff69cc-fec1-4fd3-9f98-93be1112a6b8           project
#
#          building_type  event_datetime_max           source event_date  \
# 0        assembly_shop 2020-05-09 17:36:38     facebook_ads 2020-05-06
# 1      research_center 2020-05-20 11:26:06     facebook_ads 2020-05-06
# ...

# %%
df_user_spent_time['event'].value_counts()
# Out:
# building            34478
# finished_stage_1     5817
# project              1866
# Name: event, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_user_spent_time, x='event_date', y=df_user_spent_time['total_hours_spend'], hue='event')
plt.title('Average by Event Over Time')
plt.xlabel('Date')
plt.ylabel('Average Hours Spend')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# jika kita lihat grafik di atas, waktu yang di habiskan pengguna untuk membangun bangunan cenderung menurun, namun sepanjang watu rata-rata waktu di habiskan untuk project dan melawan bos cenderung meningkat namun stabil

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_user_spent_time, x='event_date', y='total_hours_spend', hue='building_type')
plt.title('Average Hour Spend by Building Type Over Time')
plt.xlabel('Date')
plt.ylabel('Average Hours')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# untuk bangunan itu sendiri, pengguna banyak menghabiskan waktu pada bangunan research center paling lama, lalu di susul dengan space port dan assembly shop. mungkin assembly shop paling mudah di bangun di bandingkan bangunan lainnya.

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_user_spent_time, x='event_date', y='total_hours_spend', hue='source')
plt.title('Average Hours by Source Over Time')
plt.xlabel('Date')
plt.ylabel('Average Hours')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# jika kita lihat grafik di atas, merupakan rata- waktu yang di lewati pengguna berdasarkan sumber cenderung menurun, karena akusisi penggunapun juga menruut jika kita lihat grafik diatas sebelumnya.

# %% [markdown]
# #### Analisa Event Building

# %%
df_final_event_build = df_user_spent_time[df_user_spent_time['event'] == 'building']
df_final_event_build
# Out:
#                                     user_id     event    building_type  \
# 0      0001f83c-c6ac-4621-b7f0-8a28b283ac30  building    assembly_shop
# 1      0001f83c-c6ac-4621-b7f0-8a28b283ac30  building  research_center
# 2      0001f83c-c6ac-4621-b7f0-8a28b283ac30  building        spaceport
# 3      00151b4f-ba38-44a8-a650-d7cf130a0105  building    assembly_shop
# 4      00151b4f-ba38-44a8-a650-d7cf130a0105  building        spaceport
# ...                                     ...       ...              ...
# 42154  ffff194a-56b7-4c12-860d-3485242ae7f5  building    assembly_shop
# 42155  ffff194a-56b7-4c12-860d-3485242ae7f5  building        spaceport
# 42156  ffff69cc-fec1-4fd3-9f98-93be1112a6b8  building    assembly_shop
# 42157  ffff69cc-fec1-4fd3-9f98-93be1112a6b8  building  research_center
# 42158  ffff69cc-fec1-4fd3-9f98-93be1112a6b8  building        spaceport
#
#        event_datetime_max                 source event_date       spend_time  \
# ...

# %%
df_final_event_build_avg_spend = df_final_event_build.groupby(['building_type']).agg({'user_id':'count','total_hours_spend':'sum'})
df_final_event_build_avg_spend = df_final_event_build_avg_spend.reset_index()
df_final_event_build_avg_spend['spent_avg_per_user'] = (df_final_event_build_avg_spend['total_hours_spend'] / df_final_event_build_avg_spend['user_id'])
df_final_event_build_avg_spend
# Out:
#      building_type  user_id  total_hours_spend  spent_avg_per_user
# 0    assembly_shop    13576       1.318753e+06           97.138572
# 1  research_center     7671       2.064447e+06          269.123637
# 2        spaceport    13231       3.252215e+06          245.802624

# %%
df_final_event_build_avg_spend_source = df_final_event_build.groupby(['source']).agg({'user_id':'count','total_hours_spend':'sum'})
df_final_event_build_avg_spend_source = df_final_event_build_avg_spend_source.reset_index()
df_final_event_build_avg_spend_source['spent_avg_per_user'] = (df_final_event_build_avg_spend_source['total_hours_spend'] / df_final_event_build_avg_spend_source['user_id'])
df_final_event_build_avg_spend_source
# Out:
#                     source  user_id  total_hours_spend  spent_avg_per_user
# 0             facebook_ads     6967       1.348252e+06          193.519678
# 1          google_play_ads    12227       2.343698e+06          191.682147
# 2    instagram_new_adverts     8521       1.649730e+06          193.607575
# 3  youtube_channel_network     6763       1.293736e+06          191.296143

# %% [markdown]
# dari data building di atas di dapat bahwa pengguna lebih banyak membangun assembly_shop lalu di susul dengan space_port dan research_center. paling lama mereka spend dalam membuat spaceport.
#
# untuk source tidak ada perbedaan yang cukup signifikan dari spend time user. namun tetap sesuai di awal, google_oplay_ads merupakan source terbaik sejauh ini untuk mengakuisisi customer.

# %% [markdown]
# #### Analisa Event Project

# %%
df_final_event_project= df_user_spent_time[df_user_spent_time['event'] == 'project']
df_final_event_project
# Out:
#                                     user_id    event building_type  \
# 42     006380d6-67a6-45de-ab1e-6eb54ad8dbe8  project    next_level
# 76     00be7371-fa79-4fbd-b8e7-8ba32e3f8f82  project    next_level
# 84     00c2b9f2-2615-439c-aed0-6974e4c6c1c1  project    next_level
# 105    00de2809-403e-4476-a2f7-ca1b11700190  project    next_level
# 114    00e83261-5fd4-4939-9616-802b5a0202c6  project    next_level
# ...                                     ...      ...           ...
# 42054  ff50f63a-c4b3-494e-8bf9-3f19dbfc513e  project    next_level
# 42065  ff60fcd1-4329-494e-b82d-461fbdf5b5eb  project    next_level
# 42086  ff83bdd8-f49a-49fd-8aad-9fa1fb30d516  project    next_level
# 42091  ff841992-d93b-462e-bc6e-18c24a514f36  project    next_level
# 42160  ffff69cc-fec1-4fd3-9f98-93be1112a6b8  project    next_level
#
#        event_datetime_max                   source event_date  \
# 42    2020-05-16 02:43:11  youtube_channel_network 2020-05-04
# ...

# %%
df_final_event_project_group = df_final_event_project.groupby('source').agg({'user_id':'count'})
df_final_event_project_group.reset_index()
# Out:
#                     source  user_id
# 0             facebook_ads      391
# 1          google_play_ads      620
# 2    instagram_new_adverts      476
# 3  youtube_channel_network      379

# %% [markdown]
# #### Analisa Event Finished stage 1

# %%
df_final_event_finished_1 = df_user_spent_time[df_user_spent_time['event'] == 'finished_stage_1']
df_final_event_finished_1
# Out:
#                                     user_id             event building_type  \
# 9      001d39dc-366c-4021-9604-6a3b9ff01e25  finished_stage_1    next_level
# 18     003ee7e8-6356-4286-a715-62f22a18d2a1  finished_stage_1    next_level
# 22     004074f8-251a-4776-922c-8348dca1a2f6  finished_stage_1    next_level
# 27     00464e5e-28ed-4be6-bf44-517ef7b3937b  finished_stage_1    next_level
# 30     0056c007-c082-43cc-bdef-afc49bca4cb9  finished_stage_1    next_level
# ...                                     ...               ...           ...
# 42137  ffd002f3-3545-423e-8dba-0c6a2d48a3aa  finished_stage_1    next_level
# 42142  ffe810f4-1a1f-464b-924d-6f120b0cb8df  finished_stage_1    next_level
# 42146  ffef4fed-164c-40e1-bde1-3980f76d0fb5  finished_stage_1    next_level
# 42153  fffb626c-5ab6-47c9-8113-2062a2f18494  finished_stage_1    next_level
# 42159  ffff69cc-fec1-4fd3-9f98-93be1112a6b8  finished_stage_1    next_level
#
# ...

# %%
df_final_event_finished_1_group = df_final_event_finished_1.groupby('source').agg({'user_id':'count'})
df_final_event_finished_1_group.reset_index()
# Out:
#                     source  user_id
# 0             facebook_ads     1150
# 1          google_play_ads     2042
# 2    instagram_new_adverts     1466
# 3  youtube_channel_network     1159

# %% [markdown]
# hasil data dari finished stage 1 dan project (membangun satelit). pertiwa tersebut menandakan bahwa games sudah selesai. artiny ajika kita ingin menyisipkan iklan,setelah project selesai pun bisa di gunakan peluang tersebut

# %% [markdown]
# ## Penguraian Data - Pengujian Hipotesis

# %%
df_user_spent_time
# Out:
#                                     user_id             event  \
# 0      0001f83c-c6ac-4621-b7f0-8a28b283ac30          building
# 1      0001f83c-c6ac-4621-b7f0-8a28b283ac30          building
# 2      0001f83c-c6ac-4621-b7f0-8a28b283ac30          building
# 3      00151b4f-ba38-44a8-a650-d7cf130a0105          building
# 4      00151b4f-ba38-44a8-a650-d7cf130a0105          building
# ...                                     ...               ...
# 42156  ffff69cc-fec1-4fd3-9f98-93be1112a6b8          building
# 42157  ffff69cc-fec1-4fd3-9f98-93be1112a6b8          building
# 42158  ffff69cc-fec1-4fd3-9f98-93be1112a6b8          building
# 42159  ffff69cc-fec1-4fd3-9f98-93be1112a6b8  finished_stage_1
# 42160  ffff69cc-fec1-4fd3-9f98-93be1112a6b8           project
#
#          building_type  event_datetime_max           source event_date  \
# 0        assembly_shop 2020-05-09 17:36:38     facebook_ads 2020-05-06
# 1      research_center 2020-05-20 11:26:06     facebook_ads 2020-05-06
# ...

# %% [markdown]
# ### Pengujian Hipotesis 1

# %% [markdown]
# - H0 (Hipotesis Nol): Rata-rata waktu menyelesaikan level melalui proyek sama dengan rata-rata waktu menyelesaikan level melalui mengalahkan musuh.
# - H1 (Hipotesis Alternatif): Rata-rata waktu menyelesaikan level melalui proyek tidak sama dengan rata-rata waktu menyelesaikan level melalui mengalahkan musuh.

# %% [markdown]
# kita perlu pisahkan dataset menjadi 2 grup 1 yang menyelesaikan level dengan project dan mengalahkan pemain boss / pemain lain

# %%
df_project = df_user_spent_time[df_user_spent_time['event'] == 'project']
combine = df_user_spent_time['user_id'].isin(df_project['user_id'])
projects = df_user_spent_time[combine]
projects
# Out:
#                                     user_id             event  \
# 38     006380d6-67a6-45de-ab1e-6eb54ad8dbe8          building
# 39     006380d6-67a6-45de-ab1e-6eb54ad8dbe8          building
# 40     006380d6-67a6-45de-ab1e-6eb54ad8dbe8          building
# 41     006380d6-67a6-45de-ab1e-6eb54ad8dbe8  finished_stage_1
# 42     006380d6-67a6-45de-ab1e-6eb54ad8dbe8           project
# ...                                     ...               ...
# 42156  ffff69cc-fec1-4fd3-9f98-93be1112a6b8          building
# 42157  ffff69cc-fec1-4fd3-9f98-93be1112a6b8          building
# 42158  ffff69cc-fec1-4fd3-9f98-93be1112a6b8          building
# 42159  ffff69cc-fec1-4fd3-9f98-93be1112a6b8  finished_stage_1
# 42160  ffff69cc-fec1-4fd3-9f98-93be1112a6b8           project
#
#          building_type  event_datetime_max                   source  \
# 38       assembly_shop 2020-05-10 07:13:51  youtube_channel_network
# 39     research_center 2020-05-12 11:30:16  youtube_channel_network
# ...

# %%
projects['total_hours_spend'].mean()
# Out:
# 256.7040192926045

# %%
df_boss= df_user_spent_time[df_user_spent_time['event'] == 'finished_stage_1']
combine_boss = df_user_spent_time['user_id'].isin(df_boss['user_id'])
boss = df_user_spent_time[combine_boss]
boss
# Out:
#                                     user_id             event  \
# 7      001d39dc-366c-4021-9604-6a3b9ff01e25          building
# 8      001d39dc-366c-4021-9604-6a3b9ff01e25          building
# 9      001d39dc-366c-4021-9604-6a3b9ff01e25  finished_stage_1
# 15     003ee7e8-6356-4286-a715-62f22a18d2a1          building
# 16     003ee7e8-6356-4286-a715-62f22a18d2a1          building
# ...                                     ...               ...
# 42156  ffff69cc-fec1-4fd3-9f98-93be1112a6b8          building
# 42157  ffff69cc-fec1-4fd3-9f98-93be1112a6b8          building
# 42158  ffff69cc-fec1-4fd3-9f98-93be1112a6b8          building
# 42159  ffff69cc-fec1-4fd3-9f98-93be1112a6b8  finished_stage_1
# 42160  ffff69cc-fec1-4fd3-9f98-93be1112a6b8           project
#
#          building_type  event_datetime_max                 source event_date  \
# 7        assembly_shop 2020-05-08 14:53:14  instagram_new_adverts 2020-05-05
# ...

# %%
boss['total_hours_spend'].mean()
# Out:
# 233.3124296914948

# %%
project_time = projects['total_hours_spend']
boss_time = boss['total_hours_spend']

alpha = 0.05 

results = st.ttest_ind(project_time, boss_time)
print('Nilai p:', results.pvalue)

if results.pvalue < alpha:
    print("terdapat perbedaan statistik signifikan!")
else:
    print("tidak ada perbadaan statistik dalam waktu penyelesaian")
# Out:
# Nilai p: 2.1852695510288922e-64
# terdapat perbedaan statistik signifikan!

# %% [markdown]
# Dengan nilai p-value yang sangat rendah, kita dapat dengan keyakinan mengatakan bahwa ada perbedaan yang signifikan dalam waktu yang dibutuhkan untuk menyelesaikan level antara pengguna yang memilih strategi proyek dan mereka yang memilih strategi mengalahkan boss.

# %% [markdown]
# ### Pengujian Hipotesis 2

# %% [markdown]
# - H0 (Hipotesis Nol): tidak ada perbedaan rata-rata **jumlah bangunan yang dibangun oleh pengguna** yang **menyelesaikan level melalui proyek dan dengan mengalahkan pemain lain**
# - H1 (Hipotesis Alternatif): ada perbedaan rata-rata **jumlah bangunan yang dibangun oleh pengguna** yang **menyelesaikan level melalui proyek dan dengan mengalahkan pemain lain**

# %%
df_project_build = projects.groupby('user_id').agg({'building_type':'count'}).reset_index().sort_values('building_type', ascending = False)
df_project_build
# Out:
#                                    user_id  building_type
# 0     006380d6-67a6-45de-ab1e-6eb54ad8dbe8              5
# 1239  a663b989-68e1-44ea-a1b4-1b92fcf19c10              5
# 1251  a80f9a17-4c62-4367-8e25-6c0a4414c2fe              5
# 1250  a7f92e27-1612-408e-902c-f4fb4f7929df              5
# 1249  a7dcbb7e-e3b7-4b81-b5f5-3577286eea44              5
# ...                                    ...            ...
# 618   51d1a7a1-a66d-4c7e-8a91-632ad7911877              5
# 617   51abf511-115e-4d94-94c5-35a70ae730c8              5
# 616   518ca98d-ec5d-439c-bbc2-a56c42e84787              5
# 615   518b43ae-2952-4438-933e-b53f5d5062d1              5
# 1865  ffff69cc-fec1-4fd3-9f98-93be1112a6b8              5
#
# [1866 rows x 2 columns]

# %%
df_boss_build = boss.groupby('user_id').agg({'building_type':'count'}).reset_index().sort_values('building_type', ascending = False)
df_boss_build
# Out:
#                                    user_id  building_type
# 5816  ffff69cc-fec1-4fd3-9f98-93be1112a6b8              5
# 1371  3a22e068-4d1b-4168-a851-4581e4ef637e              5
# 1368  39eddc0c-47be-4a85-b754-a60c0b9bbc2b              5
# 1367  39ebcf70-e56e-4482-893b-44d1367272f0              5
# 1365  39e0d1fd-839e-4f90-8a65-049bf3b6ef08              5
# ...                                    ...            ...
# 2079  5ae0ea10-8411-4642-872a-21adb57ae0f4              2
# 4067  b27ae5e5-1df7-4eb1-8609-b7828148476c              2
# 2749  78c4c3f9-8561-4b41-9051-6ac9b7b03dd1              2
# 2464  6d08f528-d44b-44f8-acda-55f03b278768              2
# 374   0f9877eb-6ac9-4658-8e4b-81eacd6cca0b              2
#
# [5817 rows x 2 columns]

# %%
project_build = df_project_build['building_type']
boss_build = df_boss_build['building_type']

alpha = 0.05

results = st.ttest_ind(project_build, boss_build)
print('Nilai p:', results.pvalue)

if results.pvalue < alpha:
    print("terdapat perbedaan statistik signifikan!")
else:
    print("tidak ada perbadaan statistik dalam waktu penyelesaian")
# Out:
# Nilai p: 0.0
# terdapat perbedaan statistik signifikan!

# %% [markdown]
# ## Kesimpulan

# %% [markdown]
# dari project yang sudah kita kerjaan ada kesimpulan-kesimpulan yang perlu kita ambil :
# - sumber iklan yang mendapatkan CAC paling murah sepanjang waktu yaitu youtube_channel_network dan google_play ads
# - jumlah customer terbanyak merupakan daru google_play ads , lalu di susul instagram namun instagram mempunya cac yang cukup tinggi dan youtube_channel_network pengguna yang di dapat lebih kecil di banding instagram. jadi google merupakan yang mempunyai perfomra iklan yang baik
# - dari demografi pengguna rata rata waktu yang di habiskan untuk event building seiring berjalanannya waktu itu menurun di bandingkan dengan project / boss, jadi untuk optimisasi kita bisa cari orang yang lebih menyukai boss / project
# - namun jika building perlu di explore, kita bisa menargetkan iklan dengan urutan research center, spaceport, assembly shop.
# - jika kita ingin memonetesasi iklan kita bisa berikan hadiah tambahan pada game tersebut setelah iklan. dengan urutan yang spend time paling lama hadiah bonus dari game paling banyak.
